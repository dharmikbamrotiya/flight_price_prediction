# %%
import streamlit as st
import joblib
import pandas as pd
import numpy as np

# Load model and encoders
model = joblib.load("flight_price_model.pkl")
oe = joblib.load("ordinal_encoder.pkl")         # Ordinal encoder: Class, Dep_Period, Arr_Period, Stop
ohe = joblib.load("onehot_encoder.pkl")         # OneHot encoder: Airline, From, To
feature_columns = joblib.load("feature_columns.pkl")  # Column order after encoding

# App Title & Image
st.title("Flight Price Predictor")
st.image(r"C:\Users\Dharmik\Downloads\85843c0f-7513-4868-9917-3dd877925a03.jpeg", width=300)

# --- User Inputs ---
airline = st.selectbox("Airline", ["Vistara", "Air India", "Indigo", "GO FIRST", "AirAsia", "SpiceJet", "StarAir", "Trujet"])
source_city = st.selectbox("Source City", ["Delhi", "Mumbai", "Bangalore", "Kolkata", "Hyderabad", "Chennai"])
departure_time = st.selectbox("Departure Time", ["Morning", "Afternoon", "Evening", "Night"])
arrival_time = st.selectbox("Arrival Time", ["Morning", "Afternoon", "Evening", "Night"])
stops = st.selectbox("Number of Stops", ['0', '1', '2'])   # Keep as string for encoder compatibility
destination_city = st.selectbox("Destination City", ["Mumbai", "Delhi", "Bangalore", "Kolkata", "Hyderabad", "Chennai"])
flight_class = st.radio("Class", ["economic", "business"])
day = st.slider("Day of the Month", 1, 31)

# --- Prediction Logic ---
if st.button("Predict Price"):
    try:
        # Step 1: Raw Input Dictionary
        input_dict = {
            'Airline': [airline],
            'From': [source_city],
            'To': [destination_city],
            'Class': [flight_class],
            'Stop': [stops],   # Keep as string
            'Dep_Period': [departure_time],
            'Arr_Period': [arrival_time],
            'Day': [int(day)]
        }

        df_input = pd.DataFrame(input_dict)

        # Step 2: Column Separation
        ordinal_cols = ['Dep_Period', 'Arr_Period', 'Class', 'Stop']
        onehot_cols = ['Airline', 'From', 'To']

        # Step 3: Ordinal Encoding
        encoded_ordinal = oe.transform(df_input[ordinal_cols])
        df_input[ordinal_cols] = encoded_ordinal

        # Step 4: OneHot Encoding
        df_encoded = pd.DataFrame(
            ohe.transform(df_input[onehot_cols]),
            columns=ohe.get_feature_names_out(onehot_cols)
        )



        # Step 5: Combine all features
        final_input = pd.concat([
            df_encoded.reset_index(drop=True),
            df_input[['Day']].reset_index(drop=True),
            df_input[ordinal_cols].reset_index(drop=True)
        ], axis=1)

        # Step 6: Align columns to model input order
        final_input = final_input.reindex(columns=feature_columns, fill_value=0)

        # Step 7: Predict
        prediction_log = model.predict(final_input)
        prediction = np.expm1(prediction_log)


        # Step 8: Display result
        st.success(f"Predicted Ticket Price: ₹{prediction[0]:,.2f}")
        
    except Exception as e:
        import traceback
        st.error("Prediction failed. See error below:")
        st.code(traceback.format_exc())
# Out:
# 2025-08-08 00:58:26.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-08 00:58:26.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
